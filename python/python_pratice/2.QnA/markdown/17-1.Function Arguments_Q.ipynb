# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ### 꼭 기억하세요 😊
# + **시간이 다소 소요되더라도** 스스로 생각해서 프로그래밍을 해야**`실력이 향상 됩니다.`**
# + 다양한 문제를 통해서 **`문제 해결`**능력을 향상 시켜봐요.
# + 여러 방식으로 **`같은 결과 값`**이 나오도록 프로그래밍 해보세요.
# + **문제 해결**에 너무 시간이 오래 걸리면 **`검색(구글링 등)`**을 통해서 해결해보세요.
# + **`온라인 Python IDE :`** https://www.programiz.com/python-programming/online-compiler/

# %% [markdown]
# ***
# ## 17. Function Arguments💻
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `아래` **`함수가 실행 시 에러가 발생하는 이유`** `를 생각해보세요.` **`함수 수정 후`** `정상적으로 실행해보세요.`
#
#
#
# ```python
#
# # 함수 선언
# def greet(msg="Good morning!", name):
#     return "Hi! " + name + ', ' + msg
#
# # 실행
# print(greet("Kim"))
# print(greet("Park", "How do you do?"))
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
# 코딩 영역
import this

# 파이썬에서는 디폴트 값이 있는 매개변수는 기본 값이 없는 매개변수보다 뒤에 와야한다. 
def greet(name, msg="Good morning!"):
    return "Hi! " + name + ', ' + msg


# 실행
print(greet("Kim"))
print(greet("Park", "How do you do?"))

# print(greet(name='Park'))
# Out:
# Hi! Kim, Good morning!
# Hi! Park, How do you do?

# %%
# 연습
# 참고 ! **num은 딕셔너리 형태로 전달된다.
def test_sum(*n,**num):

    return sum(n) + sum(num.values())
print(test_sum(1, 2, 3, 4, 5,num=6, num2=7 , num3=9))
# Out:
# 37

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # 파이썬 함수 인자 실행 순서는 중요해요.
# # 함수 정의시 가변인자, 기본값 등을 사용하면 활용도와 가독성이 높게 작성할 수 있어요.
# # 참고 : https://levelup.gitconnected.com/5-types-of-arguments-in-python-function-definition-e0e2a2cafd29
# ```
# <br/>
# <img src="../source/17-1.jpg" alt="MarineGEO circle logo"/>
# </div>
# </details>

# %% [markdown]
# ***
